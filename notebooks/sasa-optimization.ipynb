# %%
import numpy as np
import math
from tqdm import tqdm
from collections import defaultdict

# %%
# ==========================================================
#           creating 3D matrix
# ==========================================================
surface_dict = defaultdict(int)

for x in range(0, 102, 1):
    for y in range(0, 102, 1):
        for z in range(0, 102, 1):
            surface_dict[(x,y,z)] = 0


# create filled bins
x_filled = np.random.randint(25, 75, 6)
y_filled = np.random.randint(25, 75, 6)
z_filled = np.random.randint(25, 75, 6)

for x, y, z in zip(x_filled, y_filled, z_filled):
    surface_dict[(x, y, z)] = 1


def check_surface(tup) -> bool:
    '''check if any neighbour is an empty bin'''
    x, y, z = tup

# %%
# Out:
# 2
